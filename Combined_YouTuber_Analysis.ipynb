# %% [markdown]
# ## Import python libraries:

# %% [markdown]
# Let's import the python libraries we pip installed one last time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Now we've cleaned both of our datasets by dropping unnecessary columns and/or rows, renaming columns, deleting and/or correcting null values, converting data types, updating incorrect values, reimplementing missing YouTubers, and ranking YouTubers in order of subscriber count (descending). <br> With the majority of the data cleaning out of the way, we can now read in both csv files.

# %% [markdown]
# ## Read in both csv files:

# %%
df_oldstats = pd.read_csv('cleaned_data/oldstats.csv')
df_newstats = pd.read_csv('cleaned_data/newstats.csv')

df_oldstats.head()
# Out:
#    23_rank                23_youtubers    23_subs  23_uploads  23_video_views  \
# 0        1                    T-Series  245000000       20082    228000000000
# 1        2                     MrBeast  166000000         741     28368841870
# 2        3  Cocomelon - Nursery Rhymes  162000000         966    164000000000
# 3        4                   SET India  159000000      116536    148000000000
# 4        5             Kids Diana Show  112000000        1111     93247040539
#
#         23_category     23_country      23_pop
# 0     Music & Dance          India  1366417754
# 1     Entertainment  United States   328239523
# 2       Educational  United States   328239523
# 3  Film & Animation          India  1366417754
# 4       Educational  United States   328239523

# %%
df_newstats.head()
# Out:
#    24_rank                24_youtubers    24_subs  24_avg_views  24_avg_likes  \
# 0        1                    T-Series  258400000        135200          5600
# 1        2                     MrBeast  236100000     104000000       4000000
# 2        3  Cocomelon - Nursery Rhymes  171400000       5100000         57100
# 3        4                   SET India  167100000         27900           996
# 4        5           ✿ Kids Diana Show  118500000       5100000         14300
#
#    24_avg_comments       24_category     24_country
# 0              223     Music & Dance          India
# 1            74000     Entertainment  United States
# 2                0       Educational  United States
# 3                7  Film & Animation          India
# 4                0       Educational  United States

# %% [markdown]
# #### Everything looks as it should so far!
# ##### Let's set the dataframe options in Pandas to display ALL cols and rows using 'None':

# %%
#setting dataframe options to display ALL cols and rows
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df_oldstats.head(None)
# Out:
#     23_rank                                       23_youtubers    23_subs  \
# 0         1                                           T-Series  245000000
# 1         2                                            MrBeast  166000000
# 2         3                         Cocomelon - Nursery Rhymes  162000000
# 3         4                                          SET India  159000000
# 4         5                                    Kids Diana Show  112000000
# 5         6                                          PewDiePie  111000000
# 6         7                                        Like Nastya  106000000
# 7         8                                      Vlad and Niki   98900000
# 8         9                                  Zee Music Company   96700000
# 9        10                                                WWE   96000000
# 10       11                                          BLACKPINK   89800000
# 11       12                                          Goldmines   86900000
# ...

# %% [markdown]
# ##### Looking over the 2023 dataset, all appears to be accurate!

# %%
df_newstats.head(None)
# Out:
#     24_rank                                       24_youtubers    24_subs  \
# 0         1                                           T-Series  258400000
# 1         2                                            MrBeast  236100000
# 2         3                         Cocomelon - Nursery Rhymes  171400000
# 3         4                                          SET India  167100000
# 4         5                                  ✿ Kids Diana Show  118500000
# 5         6                                        Like Nastya  112600000
# 6         7                                          PewDiePie  111600000
# 7         8                                      Vlad and Niki  109600000
# 8         9                                  Zee Music Company  104500000
# 9        10                                                WWE   99000000
# 10       11                                          Goldmines   94000000
# 11       12                                          BLACKPINK   93200000
# ...

# %% [markdown]
# ##### Looking over the 2024 dataset, it also appears to be accurate!

# %% [markdown]
# ## Merging the datasets:

# %%
#we'll use concatenate since we don't have a key column to join off of
df_combined = pd.concat([df_oldstats, df_newstats], axis=1)
df_combined.head(5)
# Out:
#    23_rank                23_youtubers    23_subs  23_uploads  23_video_views  \
# 0        1                    T-Series  245000000       20082    228000000000
# 1        2                     MrBeast  166000000         741     28368841870
# 2        3  Cocomelon - Nursery Rhymes  162000000         966    164000000000
# 3        4                   SET India  159000000      116536    148000000000
# 4        5             Kids Diana Show  112000000        1111     93247040539
#
#         23_category     23_country      23_pop  24_rank  \
# 0     Music & Dance          India  1366417754        1
# 1     Entertainment  United States   328239523        2
# 2       Educational  United States   328239523        3
# 3  Film & Animation          India  1366417754        4
# 4       Educational  United States   328239523        5
#
#                  24_youtubers    24_subs  24_avg_views  24_avg_likes  \
# 0                    T-Series  258400000        135200          5600
# ...

# %% [markdown]
# ## Create new csv of merged datasets:

# %% [markdown]
# This csv will be the one used in Tableau for more visuals.

# %%
#commented out the code below to avoid creating another comb_stats csv file
#df_combined.to_csv('comb_dataset/comb_stats.csv', index=False)

# %% [markdown]
# ## Finding Insights:

# %% [markdown]
# Now that we got these datasets combined, let's break down on how we can get the total number of YouTubers for each country in this timeline.

# %%
#let's combine the YouTuber and country columns for each pair ('23 YouTuber/'23 Country and '24 YouTuber/'24 Country)
df_combined['Pair_1'] = df_combined["23_youtubers"] + '_' + df_combined["23_country"]
df_combined['Pair_2'] = df_combined["24_youtubers"] + '_' + df_combined["24_country"]

#stack pairs and count the occurrences of YouTubers in countries
combined_pairs = pd.concat([df_combined['Pair_1'], df_combined['Pair_2']])
country_counts = combined_pairs.value_counts().reset_index()
country_counts.columns = ['country_youtuber_pair', 'count']

#now we'll split the combined pairs back into YouTuber and country
country_counts[['youtuber', 'country']] = country_counts['country_youtuber_pair'].str.split('_', expand=True)

#count the distinct number of times all YouTubers are associated with each country
distinct_country_counts = country_counts.groupby('country')['youtuber'].nunique().reset_index()
distinct_country_counts.columns = ['country', 'distinct_youtuber_count']

#sort the dataframe in descending order based on the distinct count of associated YouTubers and then by country for alphabetical order
distinct_country_counts_sorted = distinct_country_counts.sort_values(by=['distinct_youtuber_count', 'country'], ascending=[False, True])

#display our results
distinct_country_counts_sorted
# Out:
#            country  distinct_youtuber_count
# 6            India                       19
# 15   United States                       18
# 12     South Korea                        3
# 9         Pakistan                        2
# 11          Russia                        2
# 0        Argentina                        1
# 1          Belarus                        1
# 2           Brazil                        1
# 3           Canada                        1
# 4            Chile                        1
# 5      El Salvador                        1
# 7            Japan                        1
# 8           Mexico                        1
# 10     Puerto Rico                        1
# 13           Spain                        1
# 14  United Kingdom                        1

# %% [markdown]
# Here we can see that India had the most YouTubers overall. Let's dig a little deeper and see why that may be.

# %%
#finding the index of the row with the maximum population
max_pop_id = df_combined["23_pop"].idxmax()

#accessing the country with the highest population
high_pop_ctry = df_combined.loc[max_pop_id, "23_country"]
ctry_pop = df_combined.loc[max_pop_id, "23_pop"]

#display our results
print("The country with the highest population is:", high_pop_ctry)
print("Population:", ctry_pop)
# Out:
# The country with the highest population is: India
# Population: 1366417754

# %% [markdown]
# Ah, so it turns out India has the highest population in our dataframe. It would make sense then that the majority of YouTubers came from the highest populated country in this dataset.

# %% [markdown]
# ## Create new dataframe with dropped cols:

# %% [markdown]
# Let's create a grouped bar chart showcasing our top 50 YouTubers and their subscriber total for the half year period so we can find some interesting estimations.

# %%
#this dataframe will cover our subscriber rankings across 2023 to 2024
df_subs_comb = df_combined.drop(columns = ["23_rank", 
                                            "23_uploads", 
                                            "23_video_views", 
                                            "23_category", 
                                            "23_country", 
                                            "23_pop", 
                                            "24_rank", 
                                            "24_avg_views", 
                                            "24_avg_likes", 
                                            "24_avg_comments", 
                                            "24_category", 
                                            "24_country", 
                                            "Pair_1", 
                                            "Pair_2"])
df_subs_comb.head(5)
# Out:
#                  23_youtubers    23_subs                24_youtubers  \
# 0                    T-Series  245000000                    T-Series
# 1                     MrBeast  166000000                     MrBeast
# 2  Cocomelon - Nursery Rhymes  162000000  Cocomelon - Nursery Rhymes
# 3                   SET India  159000000                   SET India
# 4             Kids Diana Show  112000000           ✿ Kids Diana Show
#
#      24_subs
# 0  258400000
# 1  236100000
# 2  171400000
# 3  167100000
# 4  118500000

# %% [markdown]
# ## Visualizations:

# %% [markdown]
# #### We'll use a multi bar plot to visualize how the subscriber count has changed between '23 and '24 for the top YouTubers:

# %%
#defining the data
labels = df_subs_comb["23_youtubers"]
subs_23 = df_subs_comb["23_subs"]
subs_24 = df_subs_comb["24_subs"]

#setting the width of the bars and the label locations
x = np.arange(len(labels))
width = 0.35

#adjusting the figsize as needed
fig, ax = plt.subplots(figsize=(15, 6))
rects1 = ax.bar(x - width/2, subs_23, width, label="23_subs")
rects2 = ax.bar(x + width/2, subs_24, width, label="24_subs")

#adding the text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel("YouTubers")
ax.set_ylabel("Subscribers (Millions)")
ax.set_title("Subscribers by YouTubers (2023 vs 2024)")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)
ax.legend()

#removed scientific notation from y-axis
plt.ticklabel_format(style='plain', axis='y')

#tight_layout method resizes the subplots so they don't overlap one another
plt.tight_layout()

plt.show()

# %% [markdown]
# From this, we can see that MrBeast gained the most subscribers between July 2023 to January 2024, but we're unable to tell the exact amount gained. Let's create a calculation to display the exact number of subscribers each YouTuber gained in the half year period and sort them in descending order.

# %%
#define the function
def diff(a, b): 
    return b - a 

#create the new column by taking both subscriber columns as arguments and then using the apply method to apply it to all the values throught the column
df_subs_comb['total_subs_gained'] = df_subs_comb.apply( 
    lambda x: diff(x["23_subs"], x["24_subs"]), axis=1)

#sorting the new column by using the .sort_values method
total_subs_sort = df_subs_comb.sort_values(by=["total_subs_gained"], ascending=False)

total_subs_sort.head(None)
# Out:
#                                          23_youtubers    23_subs  \
# 1                                             MrBeast  166000000
# 0                                            T-Series  245000000
# 7                                       Vlad and Niki   98900000
# 2                          Cocomelon - Nursery Rhymes  162000000
# 3                                           SET India  159000000
# 8                                   Zee Music Company   96700000
# 4                                     Kids Diana Show  112000000
# 11                                          Goldmines   86900000
# 12                                           Sony SAB   83000000
# 6                                         Like Nastya  106000000
# 15                                      Justin Bieber   71600000
# 23                              T-Series Bhakti Sagar   61000000
# 18        Pinkfong Baby Shark - Kids' Songs & Stories   68200000
# ...

# %% [markdown]
# The calculation above under the, "total_subs_gained" column shows us that MrBeast stood out by adding on an estimated total of 70,100,000 subscribers from then to now! <br> Check out the most watched MrBeast video below to see how popular his videos are:

# %%
# %%HTML
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/0e3GPea1Tyg"
# </iframe>
# Out:
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/0e3GPea1Tyg"
# </iframe>

# %% [markdown]
# The least subscriber difference among all repeat YouTubers in this half year period was 5-minute Crafts, gaining only an estimated total of 500,000 subscribers (which is, nonetheless, still impressive). <br> Check out the video below to view an example of what 5-minute Crafts is all about:

# %%
# %%HTML
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/Ez6Yrnh4w6k"
# </iframe>
# Out:
# <iframe width="414" height="250"
#  src="https://www.youtube.com/embed/Ez6Yrnh4w6k"
# </iframe>

# %% [markdown]
# Below, I created a trimmed display of the original grouped bar chart. Both bar charts display a decently steady trend (excluding MrBeast and 5-minute Crafts) on the top YouTubers increasing their subscriber count from 2023 to 2024.

# %% [markdown]
# #### Showcasing the top 15 YouTubers for a better close-up:

# %%
df_subs_comb = df_subs_comb.head(15)

#defining the data
labels = df_subs_comb["23_youtubers"]
subs_23 = df_subs_comb["23_subs"]
subs_24 = df_subs_comb["24_subs"]

#setting the width of the bars and the label locations
width = 0.35
x = np.arange(len(labels)) 

#adjusting the figsize as needed
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, subs_23, width, label="23_subs")
rects2 = ax.bar(x + width/2, subs_24, width, label="24_subs")

#adding the text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel("YouTubers")
ax.set_ylabel("Subscribers (Millions)")
ax.set_title("Subscribers by YouTubers (2023 vs 2024)")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)
ax.legend()

#removed scientific notation from y-axis
plt.ticklabel_format(style='plain', axis='y')

#resizes the subplots so they don't overlap one another
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Some visualizations were created in Tableau. Reference the README section for the url link, "YouTuber Visuals". <br> Or click [here](https://public.tableau.com/app/profile/emmett.blair/viz/YouTuberVisuals/YouTuberVisuals?publish=yes).
